# %%
import wraplorenzmie.utilities.utilities as utilities
import wraplorenzmie.fits.fit as fit
import imageio
# For Plotting.
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#sns.set(style='white', font_scale=2)
# %matplotlib inline
import matplotlib as mpl


mpl.rcParams["figure.dpi"] = 130
from matplotlib import rc
rc('font', family='serif')
rc('text', usetex=False)
rc('xtick', labelsize='x-small')
rc('ytick', labelsize='x-small')

def cm2inch(value):
    return value/2.54
# Out:
# INFO:pylorenzmie.theory:Could not import CUDA GPU pipeline. No module named 'cupy'
# No module named 'pylorenzmie.fitting.cython.cminimizers'

# %%
vid = utilities.video_reader("Basler_acA1920-155um__22392621__20210204_164722049.mp4")

# %%
def radial_profile(data, center=None):
    if center==None:
        center = np.array(np.shape(data)) / 2
    
    y, x = np.indices((data.shape))
    r = np.sqrt((x - center[0])**2 + (y - center[1])**2)
    r = r.astype(np.int)

    tbin = np.bincount(r.ravel(), data.ravel())
    nr = np.bincount(r.ravel())
    radialprofile = tbin / nr
    
    T = data.ravel()
    V = r.ravel()
    
    err = [np.std(T[V == u]) for u in np.unique(V)]
    
    return radialprofile, err

# %%
image = vid.get_image(1)
plt.imshow(image,cmap="gray")

# %%
vid.number = 14000
vid.background = np.array(imageio.imread("background.tiff"))
#background = vid.get_background(30)
plt.imshow(vid.background,cmap="gray")

# %%
imageio.imwrite("background.tiff",vid.background)

# %%
normed_image = utilities.normalize(image,vid.background)
plt.imshow(normed_image,cmap="gray")
normed_image = normed_image

# %%
feature, circ = utilities.center_find(image)
feature
# Out:
# array([[509.26918095,  24.78986667, 400.        , 400.        ],
#        [184.01544622,  72.80434783, 400.        , 400.        ],
#        [766.92790344,  98.74342579, 400.        , 400.        ],
#        [ 76.23045908, 113.56659829, 400.        , 400.        ],
#        [217.37031433, 139.34913234, 400.        , 400.        ],
#        [853.43139852, 292.72411375, 400.        , 400.        ],
#        [ 73.37344044, 325.41274996, 400.        , 400.        ],
#        [476.85366072, 357.94309526, 400.        , 400.        ],
#        [199.89587374, 372.39684359, 400.        , 400.        ],
#        [653.82502543, 412.45581129, 400.        , 400.        ],
#        [216.18888783, 514.43172329, 400.        , 400.        ],
#        [841.89591535, 506.47896161, 400.        , 400.        ],
#        [444.21270537, 514.4207667 , 400.        , 400.        ],
#        [600.62347016, 540.29882298, 400.        , 400.        ],
#        [607.53285443, 618.2067047 , 400.        , 400.        ],
#        [471.25171472, 604.2745555 , 400.        , 400.        ],
#        [532.99364983, 608.15278198, 400.        , 400.        ],
#        [751.37588301, 634.56890889, 400.        , 400.        ],
#        [410.1304917 , 645.60705228, 400.        , 400.        ],
#        [525.00146972, 692.60949442, 400.        , 400.        ],
#        [ 43.11224177, 744.16845461, 400.        , 400.        ],
#        [320.87424015, 758.25236944, 400.        , 400.        ],
#        [828.78992102, 789.88238324, 400.        , 400.        ],
#        [459.52251966, 819.54944793, 400.        , 400.        ],
#        [622.29460232, 821.86032173, 400.        , 400.        ],
#        [729.42912333, 860.07434373, 400.        , 400.        ],
#        [464.02257123, 872.1594576 , 400.        , 400.        ],
#        [268.08479696, 869.91835326, 400.        , 400.        ]])

# %%
feature = np.array([[430,  430, 200.        , 200.        ]])
feature
# Out:
# array([[430., 430., 200., 200.]])

# %%
utilities.plot_bounding(normed_image,feature)

# %%
x, y, w, h = feature[0]
x = x - 6
y = y + 5
x_center = x 
y_center = y
h=250
im_c = fit.crop(image, int(x), int(y), int(h))
bk_c = fit.crop(vid.background, int(x), int(y), int(h))
cropped = utilities.normalize(im_c,bk_c, dark_count = np.min(im_c))
cropped = cropped / np.mean(cropped)
plt.imshow(cropped,cmap = "gray")

# %%
fitter = fit.fitting(cropped,0.532,0.0535, n_m = 1.33)
fitter.make_guess(1.5,1.59,40,alpha = 1,fit_r=True, fit_n=True,fit_alpha=True)

# %%
#%timeit result = fitter.fit_single(cropped, method = "lm")
result = fitter.fit_single(cropped, method = "lm")

# %%
zo = result.result["x"][2]*0.052
print(result.result["x"][2]*0.052)
print(result.redchi)
print(result.result["x"])
# Out:
# 32.88415695776699
# 16.478304446988247
# [126.24852447 124.0206876  632.3876338    1.27710508   1.64955155
#    1.01797332]

# %%
result.result.x
# Out:
# array([126.24852447, 124.0206876 , 632.3876338 ,   1.27710508,
#          1.64955155,   1.01797332])

# %%
result.result
# Out:
#  active_mask: array([0, 0, 0, 0, 0, 0])
#         cost: 51445.26648349731
#          fun: array([3.7937448 , 1.98465426, 0.50585736, ..., 0.10159131, 1.27874472,
#        1.60887827])
#         grad: array([ 1.40103319e+00,  3.40194384e+00, -2.02928671e+00, -4.01292685e+02,
#        -2.41313491e+03, -1.51469588e+02])
#          jac: array([[-7.78225647e-01, -1.59783072e-01, -3.58465498e-02,
#          3.12456905e+01,  6.42373342e+01,  3.06340818e+01],
#        [-7.94056190e-01,  3.39981529e-01, -4.60329951e-02,
#          3.06512068e+01,  1.10828341e+02,  4.13971860e+01],
#        [-4.72555360e-02,  4.20939021e-01, -2.74808388e-02,
#          5.41137629e+01,  1.24713911e+02,  5.50493520e+01],
#        ...,
#        [-5.18601972e-03,  4.89991725e-01,  1.18915299e-02,
#         -5.78132613e+01, -7.71221623e+01,  3.49084503e+01],
#        [-2.00666896e-01,  3.13161409e-01,  4.39240438e-02,
#         -7.83833258e+00, -6.87435101e+01,  4.21795974e+01],
#        [-2.52602581e-01,  6.88630708e-01,  5.12218941e-02,
#          1.69782230e+01, -7.10100134e+01,  4.59272118e+01]])
#      message: '`ftol` termination condition is satisfied.'
#         nfev: 43
#         njev: None
#   optimality: 2413.1349108738104
#       status: 2
#      success: True
#            x: array([126.24852447, 124.0206876 , 632.3876338 ,   1.27710508,
#          1.64955155,   1.01797332])

# %%
np.linalg.inv(np.dot(np.transpose(result.result.jac), result.result.jac))
# Out:
# array([[ 1.06193830e-03, -3.20170304e-06,  2.85988868e-04,
#          3.63948609e-07, -1.09360348e-07,  1.29008726e-07],
#        [-3.20170304e-06,  1.05425765e-03,  2.42852675e-04,
#         -2.55741402e-07,  1.05078164e-07, -4.27728442e-09],
#        [ 2.85988868e-04,  2.42852675e-04,  9.57135569e-01,
#         -4.43371337e-04,  4.79305905e-04, -1.37278402e-04],
#        [ 3.63948609e-07, -2.55741402e-07, -4.43371337e-04,
#          6.62291257e-07, -3.22136709e-07,  9.04690300e-09],
#        [-1.09360348e-07,  1.05078164e-07,  4.79305905e-04,
#         -3.22136709e-07,  2.91962940e-07, -7.61026942e-08],
#        [ 1.29008726e-07, -4.27728442e-09, -1.37278402e-04,
#          9.04690300e-09, -7.61026942e-08,  1.25284220e-07]])

# %%
np.shape(result.result.fun)
# Out:
# (6250,)

# %%
np.shape(fitter.image.flatten())
# Out:
# (62500,)

# %%
fitter.show_results()

# %%
center = np.array(np.shape(fitter.image))

# %%
radial_exp, err = radial_profile(fitter.image)

# %%
np.shape(radial_exp)
# Out:
# (177,)

# %%
radial_exp, err = radial_profile(fitter.image)
theo_exp, err = radial_profile(fitter.fitter.model.hologram().reshape(fitter.shape))

radius_radial = np.arange(len(radial_exp))
plt.plot(radius_radial, radial_exp, label="Experimental")
plt.fill_between(radius_radial, radial_exp - err, radial_exp + err, alpha = 0.3)
plt.plot(radius_radial, theo_exp, label="Theory")
plt.legend()
plt.xlabel("radius [pixel]")
plt.ylabel("Intensity [a.u.]")
#plt.figure(figsize=(cm2inch(8.6),1.65*cm2inch(8.6)))
# Out:
# Text(0, 0.5, 'Intensity [a.u.]')

# %%
sigma = np.sum((fitter.image - fitter.fitter.model.hologram().reshape(fitter.shape)) ** 2)
H_1 = np.linalg.inv(np.dot(np.transpose(result.result.jac), result.result.jac))

error = 1.96 * np.sqrt(sigma * np.diag(H_1)) * [0.0513,0.0513,0.0513,1,1,1]

# %%
error
# Out:
# array([0.16369366, 0.16310061, 4.91438237, 0.07968735, 0.0529089 ,
#        0.03465876])

# %%
fit_data = {}


fig = plt.figure(figsize=(cm2inch(8.6),1.65*cm2inch(8.6)))
fig.subplots_adjust(left=0.14, bottom=.12, right=.99, top=.98)

plt.subplot(2,2,1)
plt.imshow(fitter.image, cmap = "gray")
#plt.title('subplot(2,2,1)')

fit_data["exp_image"] = fitter.image

plt.subplot(2,2,2)
plt.imshow(fitter.fitter.model.hologram().reshape(fitter.shape), cmap = "gray")
frame1 = plt.gca()
frame1.axes.yaxis.set_ticklabels([])

fit_data["th_image"] = fitter.fitter.model.hologram().reshape(fitter.shape)


#plt.title('subplot(2,2,2)')

plt.subplot(2,2,(3,4))
plt.plot(radius_radial, radial_exp, label="Experimental")
plt.fill_between(radius_radial, radial_exp - err, radial_exp + err, alpha = 0.3)
plt.plot(radius_radial, theo_exp, label="Theory")
plt.legend()
plt.xlabel("radius [pixel]")
plt.ylabel("Intensity [a.u.]")

fit_data["I_r_exp"] = radial_exp
fit_data["I_errr_exp"] = err

fit_data["theo_exp"] = theo_exp
fit_data["I_radius"] = radius_radial

fig.set_size_inches(cm2inch(8.6), cm2inch(1.6 * 8.6/1.618))
plt.savefig("fit_fig.pdf")

# %%
from scipy.io import savemat
savemat("data_fit_2705.mat", fit_data)

# %%
fitter.fit_video(vid = vid,savefile="find_nr.dat",xc = x ,yc= y, h = 250, n_end=500,method = "lm", dark_count_mode="min")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 499/499 [02:01<00:00,  4.11it/s]

# %%
n_r = np.fromfile('find_nr.dat', dtype=np.float64)
n_r = n_r.reshape(len(n_r)//10,10)
r = n_r[:,3]
n = n_r[:,4]

# %%
plt.plot(r)

# %%
sns.distplot(r)
# Out:
# C:\Users\m.lavaud\.conda\envs\holopy\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
np.mean(n)
# Out:
# 1.5954322155013152

# %%
np.mean(r)
# Out:
# 1.4455928819759378

# %%
H, xedges, yedges = np.histogram2d(n, r, bins=100)
H = H.T  # Let each row list bins with common y range.


plt.hist2d(r,n, bins = 150)
plt.ylabel("n")
plt.xlabel("r [$\mathrm{\mu m}$]")
# Out:
# Text(0.5, 0, 'r [$\\mathrm{\\mu m}$]')

# %%
data = np.random.multivariate_normal((0, 0), [[0.8, 0.05], [0.05, 0.7]], 100)

# %%
import numpy as np
import matplotlib.pyplot as pl
import scipy.stats as st

data = np.random.multivariate_normal((0, 0), [[0.8, 0.05], [0.05, 0.7]], 100)
x = r#[(r>2.47) & (r<2.51)]
y = n#[(r>2.47) & (r<2.51)]
xmin, xmax = np.min(x), np.max(x)
ymin, ymax = np.min(y), np.max(y)

# Peform the kernel density estimate
xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([xx.ravel(), yy.ravel()])
values = np.vstack([x, y])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)
f = f/np.max(f)

fig = plt.figure()
ax = fig.gca()
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
# Contourf plot
cfset = ax.contourf(xx, yy, f, cmap='Blues')
## Or kernel density estimate plot instead of the contourf plot
#ax.imshow(np.rot90(f), cmap='Blues', extent=[xmin, xmax, ymin, ymax])
# Contour plot
cset = ax.contour(xx, yy, f, colors='k', levels=6)
# Label plot
ax.clabel(cset, inline=1, fontsize=8, fmt="%1.1f")
plt.scatter(xx[np.where(f == 1)],yy[np.where(f == 1)], color = "red", marker="+")
ax.set_xlabel("r [$\mathrm{\mu m}$]")
ax.set_ylabel("n")
plt.title("KDE r n")

#pl.show()
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-38-e8d96e776b95> in <module>
#      15 kernel = st.gaussian_kde(values)
#      16 f = np.reshape(kernel(positions).T, xx.shape)
# ---> 17 f = f/np.max(f)
#      18
#      19 fig = plt.figure()
#
# FloatingPointError: underflow encountered in true_divide

# %%
print(" n determined with : mu={0}, sigma={1}".format(np.mean(yy[np.where(f > 0.2)]), np.std(yy[np.where(f > 0.2)])))
print(" r determined with : mu={0}, sigma={1}".format(np.mean(xx[np.where(f > 0.2)]), np.std(xx[np.where(f > 0.2)])))

mu_n, sigma_n = np.mean(yy[np.where(f > 0.2)]), np.std(yy[np.where(f > 0.2)])
mu_r, sigma_r = np.mean(xx[np.where(f > 0.2)]), np.std(xx[np.where(f > 0.2)])
mu_n = np.mean(n)
mu_r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d57405c3843e> in <module>
# ----> 1 print(" n determined with : mu={0}, sigma={1}".format(np.mean(yy[np.where(f > 0.2)]), np.std(yy[np.where(f > 0.2)])))
#       2 print(" r determined with : mu={0}, sigma={1}".format(np.mean(xx[np.where(f > 0.2)]), np.std(xx[np.where(f > 0.2)])))
#       3
#       4 mu_n, sigma_n = np.mean(yy[np.where(f > 0.2)]), np.std(yy[np.where(f > 0.2)])
#       5 mu_r, sigma_r = np.mean(xx[np.where(f > 0.2)]), np.std(xx[np.where(f > 0.2)])
#
# NameError: name 'yy' is not defined

# %%
mu_n=np.mean(n)
mu_r=np.mean(r)

# %%
import warnings
warnings.filterwarnings('ignore')
#del fitter
fitter = fit.fitting(cropped,0.532,0.0535, n_m = 1.33)
fitter.make_guess(mu_r,mu_n,zo,alpha = 1,fit_r=False, fit_n=False,fit_alpha=False)
#result = fitter.fit_single(cropped, method = "lm")
fitter.fit_video(vid = vid,savefile="fit_result_8p9uM_15022021_n_1p5883r_1p504fix_0p052_wav_532.dat",xc = x_center ,yc= y_center, h = 250, n_end=vid.number,method = "lm")
# Out:
#  73%|███████████████████████████████████████████████████████▏                    | 10173/13999 [23:57<09:00,  7.08it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-8862c1f91628> in <module>
#       5 fitter.make_guess(mu_r,mu_n,zo,alpha = 1,fit_r=False, fit_n=False,fit_alpha=False)
#       6 #result = fitter.fit_single(cropped, method = "lm")
# ----> 7 fitter.fit_video(vid = vid,savefile="fit_result_8p9uM_15022021_n_1p5883r_1p504fix_0p052_wav_532.dat",xc = x_center ,yc= y_center, h = 250, n_end=vid.number,method = "lm")
#
# ~\.conda\envs\holopy\lib\site-packages\wraplorenzmie\fits\fit.py in fit_video(self, xc, yc, vid, savefile, h, n_start, n_end, method, dark_count_mode)
#     113                     image = image
#     114
# --> 115             self.result = self.fit_single(image, method=method)
#     116             self._globalize_result()
#     117             self.save_result(n)
#
# ~\.conda\envs\holopy\lib\site-packages\wraplorenzmie\fits\fit.py in fit_single(self, image, method)
#      70             self.fitter.model.instrument.background = 1
#      71         self.fitter.model.coordinates = Instrument.coordinates(self.shape)
# ---> 72         self.fitter.data = (image).reshape(image.size)
#      73         return self.fitter.optimize(method=method)
#      74
#
# ~\.conda\envs\holopy\lib\site-packages\pylorenzmie\theory\Feature.py in data(self, data)
#     123                 logger.warning(msg.format(avg))
#     124             # Find indices where data is saturated or nan/inf
# --> 125             self.saturated = np.where(data == np.max(data))[0]
#     126             self.nan = np.append(np.where(np.isnan(data))[0],
#     127                                  np.where(np.isinf(data))[0])
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\.conda\envs\holopy\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2703     5
#    2704     """
# -> 2705     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2706                           keepdims=keepdims, initial=initial, where=where)
#    2707
#
# ~\.conda\envs\holopy\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.fromfile('fit_result_8p9uM_15022021_n_1p5883r_1p504fix_0p052_wav_532.dat', dtype=np.float64)
data = data.reshape(len(data)//10,10)
#data = data[:115000,:]
x = data[:,0]*0.052
y = data[:,1]*0.052
z = data[:,2]*0.052

# %%
import numpy as np
import scipy.io as sio

# %%
sio.savemat("fit_result_16p3uM_05022021_n_1p5904r_2p492fix_0p052_wav_532.mat", {'data':data})

# %%
plt.plot(x)
plt.plot(y)

# %%
plt.plot(z[:45000])

# %%
shape(data)

# %%
data
